# %%
#!pip3 install tweepy
import tweepy
import matplotlib.pyplot as plt
import time,sys
from textblob import TextBlob

# %%
#all 4  authentication keys to access api
 consumerkey ='s6cwmnLST2K2ZOwBnxpMMY4NI'
 consumersecret='zw7uXtlfGUy65SGwNaVTdO32spYfjF52wyxcZDu1bAwjGmKKxs'
  
 accessToken='1144188534103793664-zjOdTtxDsdR9XLvZEmL8gggpoSi0B1'
 accessTokenSecret='vJrIpTBPdoBy5nEeyVIMupQ9g61QwrjHzHtu8NjhPZWPY'

# %%
auth = tweepy.OAuthHandler(consumer_key=consumerkey, consumer_secret=consumersecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
tweets=api.search('modi',count=20)
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fa3596e1550>, _json={'created_at': 'Fri Jul 05 09:02:30 +0000 2019', 'id': 1147068222711242753, 'id_str': '1147068222711242753', 'text': 'RT @IAMSJ___: انتم متى بتستوعبون ان السوجو اكثر فرقة شهره عند العرب سواء عجبكم او لا، فان او هيتر، ورايك مابيأثر على حقيقة الواقع', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'IAMSJ___', 'name': 'شلقطي OT7', 'id': 983064250619957248, 'id_str': '983064250619957248', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 963912603260084224, 'id_str': '963912603260084224', 'name': 'modi.AG🎓', 'screen_name': 'modi_ag', 'location': '', 'descripti
# ...

# %%
positive = 0
negative = 0
neutral = 0
polarity = 0 

for tweet in tweets:
    analysis = TextBlob(tweet.text)
    polarity += analysis.sentiment.polarity
    
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0 ):
        negative += 1
    elif(analysis.sentiment.polarity > 0):
        positive += 1

print(positive)
print(negative)
print(neutral)
positive =  format(positive, '.2f')
negative =  format(negative, '.2f')
neutral =  format(neutral, '.2f')
# Out:
# 6
# 2
# 11

# %%
#get_ipython().run_line_magic('matplotlib', 'inline')
labels = ['Positive ['+str(positive)+'%]', 'Negative ['+str(negative)+'%]', 'Neutral ['+str(neutral)+'%]']
sizes = [positive, negative, neutral]
colors = ['yellowgreen', 'red', 'blue']
explode = (0.1,0,0)
patches, texts = plt.pie(sizes, colors=colors, explode=explode )

plt.legend(patches, labels, loc='best')
plt.title("People reaction on the " +searchFor)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
plt.xlabel("tags")
plt.ylabel("polarity")
plt.bar(['pos','neg','neu'],[positive,negative,neutral])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie([positive,negative,neutral],labels=["pos","neg","neu"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa359788e48>,
# ...
#  [Text(0.6016430102375327, 0.9208831023709363, 'pos'),
#   Text(-0.7450096669744859, 0.8092963586440791, 'neg'),
#   Text(-0.27003412518360026, -1.0663402699121551, 'neu')])
